# %%
from pymodulon.compare import *
from pymodulon.io import *
from pymodulon.plotting import *

import matplotlib.patches as mpatches

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['font.sans-serif']='Arial'

# %%
paeru1_data=load_json_model('../../modulome_paeru1.0/paeru_104_imodulon_ica.json')

# %%
paeru1_data.M
# Out:
#           NarL-1      DhcR  Uncharacterized-1      EatR      AtuR    HexR-1  \
# PA0001 -0.001776 -0.011492          -0.005810 -0.001476  0.008095 -0.000116
# PA0002 -0.005393 -0.007495           0.001312 -0.005358  0.012951 -0.000871
# PA0003  0.007267 -0.012053          -0.015541 -0.007606 -0.005152 -0.001478
# PA0004  0.001858 -0.001039          -0.002193 -0.002362 -0.002556  0.001095
# PA0005 -0.005459  0.001290           0.005342  0.002208 -0.006422 -0.002729
# ...          ...       ...                ...       ...       ...       ...
# PA5566 -0.021424  0.012818          -0.006129  0.009740  0.012604 -0.005379
# PA5567  0.004464 -0.001969           0.005441 -0.016585 -0.000952  0.000256
# PA5568 -0.002358 -0.005999          -0.020523 -0.005253 -0.011008 -0.000685
# PA5569 -0.004405  0.001804          -0.007775  0.006484  0.009926 -0.008311
# PA5570 -0.006915 -0.013051          -0.005597 -0.010108 -0.011070 -0.001844
#
# ...

# %%
paeru2_data=load_json_model('../paeru_116_iModulon.json')
paeru2_data.M
# Out:
#             LexA      EatR      PrrF    RpoS-2      CbrB      CueR  \
# PA0001  0.007134 -0.002035  0.001235  0.010216  0.005846 -0.006611
# PA0002  0.003392 -0.006707 -0.004633  0.003620 -0.000588 -0.006373
# PA0003  0.002395 -0.008381  0.000433 -0.001993 -0.004243 -0.020139
# PA0004  0.010033 -0.001370  0.006828 -0.004688  0.000440 -0.005297
# PA0005  0.000462  0.002844 -0.014299 -0.004383 -0.003309 -0.004760
# ...          ...       ...       ...       ...       ...       ...
# PA5566  0.005247  0.011319 -0.011385  0.008417 -0.008319 -0.005494
# PA5567  0.003643 -0.016494 -0.001808 -0.008123  0.000384 -0.002045
# PA5568  0.003530 -0.006957  0.000867 -0.005408 -0.004746 -0.007903
# PA5569  0.012624  0.006967 -0.001692  0.000169 -0.002332  0.001535
# PA5570 -0.003077 -0.014950 -0.016607 -0.000745 -0.008224 -0.002226
#
#         Translational-2      PprB    PhhR-1      DhcR  ...      NarL  \
# PA0001        -0.006853 -0.003378 -0.006825 -0.004803  ...  0.005397
# ...

# %%
dots,links = compare_ica(paeru1_data.M, paeru2_data.M,  cutoff=0.2,show_all=True)
dots

dots.render('subsets',cleanup=True)
# Out:
# ...
# 'subsets.pdf'

# %%
links
# Out:
# [('NarL-1', 'Anr-3', 0.8959326179270721),
#  ('DhcR', 'DhcR', 0.8601906430527965),
#  ('Uncharacterized-1', 'Uncharacterized-14', 0.8993854747276718),
#  ('EatR', 'EatR', 0.9312189412968886),
#  ('AtuR', 'AtuR', 0.9673977071632937),
#  ('HexR-1', 'HexR-1', 0.973105570686303),
#  ('ArgR-1', 'ArgR-1', 0.9704518620017714),
#  ('AntR', 'AntR', 0.9524381529475507),
#  ('EutR', 'EutR', 0.8613638516156616),
#  ('PmrA', 'PmrA', 0.9490599600934883),
#  ('Zur-1', 'Zur-2', 0.9944384904474024),
#  ('AHL', 'AHL', 0.9184528469104739),
#  ('TagR1', 'TagR1', 0.9790211693879121),
#  ('Uncharacterized-2', 'Uncharacterized-12', 0.9687957998926209),
#  ('ErbR-1', 'ErbR-1', 0.9801617145978246),
#  ('LasR', 'LasR', 0.9664846055686609),
#  ('Translational-1', 'Translational-1', 0.9487878348737125),
#  ('RpoN', 'RpoN', 0.9081371446548554),
#  ('MexZ', 'MexZ', 0.9695285642312346),
#  ('FruR', 'FruR', 0.9603345068823842),
#  ('MmsR', 'MmsR', 0.93139219691767),
#  ('Anr-1', 'Anr-1', 0.6058031963200213),
# ...
