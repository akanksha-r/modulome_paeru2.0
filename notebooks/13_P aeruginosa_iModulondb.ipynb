# %% [markdown]
# # Pseudomonas Aeruginosa Modulome

# %%
from pymodulon.core import IcaData
from pymodulon.io import *
from pymodulon.imodulondb import *
from pymodulon.util import *
import pandas as pd

# %% [markdown]
# ## Load and Initial Check

# %%
ica_data = load_json_model('../paeru_116_iModulon.json')

# %%
pd.set_option('display.max_colwidth', None)

table_issues, tf_issues, missing_gene_links, missing_dois = \
    imodulondb_compatibility(ica_data)

print('--Table Issues--')
display(table_issues)
print('--TF Issues--')
display(tf_issues)
print('--Missing Gene Links--')
display(missing_gene_links.values)
print('--Missing DOIs--')
display(missing_dois.values)
# Out:
# iModulon Table is missing a name column
# iModulon Table is missing a TF column
# Note that TF is used for coding purposes, so it uses '+' and '/' and must match the trn.
# iModulon Table is missing a Regulator column
# Note that Regulator is displayed in the dataset page so it can have spelled out 'and' and 'or' operators.If you have a TF column, a Regulator column will begenerated for you (but not vice versa).
# iModulon Table is missing a Function column
# iModulon Table is missing a Category column
# iModulon Table is missing a n_genes column
#
# Gene Table is missing the optional length column
# Gene Table is missing the optional operon column
#
# Sample Table is missing the optional sample column
# The 0th column will be used to define the names of samples in the activity bar graph unless you add this column.
# Sample Table is missing a Biological Replicates column
# Sample Table is missing the optional DOI column
# If you would like to be able to access papers by clicking the activity bars, add this column and populate it with links.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ca8b2ad62222> in <module>
#       1 pd.set_option('display.max_colwidth', None)
#       2
# ----> 3 table_issues, tf_issues, missing_gene_links, missing_dois = \
#       4     imodulondb_compatibility(ica_data)
#       5
#
# TypeError: cannot unpack non-iterable NoneType object

# %% [markdown]
# ## Add the iModulonDB Table

# %%
ica_data.imodulondb_table = {
     'organism': 'Pseudomonas aeruginosa',
     'dataset': 'aeruPRECISE411',
     'strain': 'PA01',
     'publication_name': 'Rajput, et al., Forthcoming',
     'publication_link': '',
     'gene_link_db': 'Pseudomonas Genome DB',
     'organism_folder': 'p_aeruginosa',
     'dataset_folder': 'modulome'
}

# %% [markdown]
# ## Add the Explained Variance

# %%
for k in ica_data.imodulon_table.index:
    ica_data.imodulon_table.loc[k, 'exp_var'] = explained_variance(
        ica_data, imodulons=k)

# %% [markdown]
# ## Sample Table

# %%
pd.set_option('display.max_rows', 370)
pd.set_option('display.max_columns', 60)
ica_data.sample_table
# Out:
#            ReleaseDate     TaxID               ScientificName  species_tax_id  \
# SRX7442752  ##########  208964.0  Pseudomonas aeruginosa PAO1             287
# SRX7442753  ##########  208964.0  Pseudomonas aeruginosa PAO1             287
# SRX7442754  ##########  208964.0  Pseudomonas aeruginosa PAO1             287
# SRX7442755  ##########  208964.0  Pseudomonas aeruginosa PAO1             287
# SRX7442756  ##########  208964.0  Pseudomonas aeruginosa PAO1             287
# ...                ...       ...                          ...             ...
# SRX2711963  ##########     287.0       Pseudomonas aeruginosa             287
# SRX2711964  ##########     287.0       Pseudomonas aeruginosa             287
# SRX2711965  ##########     287.0       Pseudomonas aeruginosa             287
# SRX2711966  ##########     287.0       Pseudomonas aeruginosa             287
# SRX2711967  ##########     287.0       Pseudomonas aeruginosa             287
#
#             class_tax_id  strain_tax_id                 species LibraryLayout  \
# SRX7442752        1236.0       208964.0  Pseudomonas aeruginosa        SINGLE
# SRX7442753        1236.0       208964.0  Pseudomonas aeruginosa        SINGLE
# SRX7442754        1236.0       208964.0  Pseudomonas aeruginosa        SINGLE
# SRX7442755        1236.0       208964.0  Pseudomonas aeruginosa        SINGLE
# SRX7442756        1236.0       208964.0  Pseudomonas aeruginosa        SINGLE
# ...                  ...            ...                     ...           ...
# SRX2711963        1236.0          287.0  Pseudomonas aeruginosa        PAIRED
# SRX2711964        1236.0          287.0  Pseudomonas aeruginosa        PAIRED
# SRX2711965        1236.0          287.0  Pseudomonas aeruginosa        PAIRED
# SRX2711966        1236.0          287.0  Pseudomonas aeruginosa        PAIRED
# SRX2711967        1236.0          287.0  Pseudomonas aeruginosa        PAIRED
#
#             Platform                Model          Run   SRAStudy  \
# SRX7442752  ILLUMINA  Illumina HiSeq 2500  SRR10768834  SRP238832
# SRX7442753  ILLUMINA  Illumina HiSeq 2500  SRR10768835  SRP238832
# SRX7442754  ILLUMINA  Illumina HiSeq 2500  SRR10768836  SRP238832
# SRX7442755  ILLUMINA  Illumina HiSeq 2500  SRR10768837  SRP238832
# SRX7442756  ILLUMINA  Illumina HiSeq 2500  SRR10768838  SRP238832
# ...              ...                  ...          ...        ...
# SRX2711963  ILLUMINA  Illumina HiSeq 2000   SRR5420449  SRP103149
# SRX2711964  ILLUMINA  Illumina HiSeq 2000   SRR5420450  SRP103149
# SRX2711965  ILLUMINA  Illumina HiSeq 2000   SRR5420451  SRP103149
# SRX2711966  ILLUMINA  Illumina HiSeq 2000   SRR5420452  SRP103149
# SRX2711967  ILLUMINA  Illumina HiSeq 2000   SRR5420453  SRP103149
#
#              BioProject  ProjectID      Sample     BioSample  Submission  \
# SRX7442752  PRJNA597754   597754.0  SRS5887073  SAMN13683003  SRA1016704
# SRX7442753  PRJNA597754   597754.0  SRS5887074  SAMN13683002  SRA1016704
# SRX7442754  PRJNA597754   597754.0  SRS5887075  SAMN13683001  SRA1016704
# SRX7442755  PRJNA597754   597754.0  SRS5887076  SAMN13682999  SRA1016704
# SRX7442756  PRJNA597754   597754.0  SRS5887077  SAMN13682998  SRA1016704
# ...                 ...        ...         ...           ...         ...
# SRX2711963  PRJNA381683   381683.0  SRS2103670  SAMN06687296   SRA551999
# SRX2711964  PRJNA381683   381683.0  SRS2103671  SAMN06687295   SRA551999
# SRX2711965  PRJNA381683   381683.0  SRS2103672  SAMN06687294   SRA551999
# SRX2711966  PRJNA381683   381683.0  SRS2103673  SAMN06687293   SRA551999
# SRX2711967  PRJNA381683   381683.0  SRS2103674  SAMN06687292   SRA551999
#
#            LibraryStrategy LibrarySelection   LibrarySource  \
# SRX7442752         RNA-Seq             cDNA  TRANSCRIPTOMIC
# SRX7442753         RNA-Seq             cDNA  TRANSCRIPTOMIC
# SRX7442754         RNA-Seq             cDNA  TRANSCRIPTOMIC
# SRX7442755         RNA-Seq             cDNA  TRANSCRIPTOMIC
# SRX7442756         RNA-Seq             cDNA  TRANSCRIPTOMIC
# ...                    ...              ...             ...
# SRX2711963         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# SRX2711964         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# SRX2711965         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# SRX2711966         RNA-Seq           RANDOM  TRANSCRIPTOMIC
# SRX2711967         RNA-Seq           RANDOM  TRANSCRIPTOMIC
#
#                                                               CenterName  \
# SRX7442752                                University of British Columbia
# SRX7442753                                University of British Columbia
# SRX7442754                                University of British Columbia
# SRX7442755                                University of British Columbia
# SRX7442756                                University of British Columbia
# ...                                                                  ...
# SRX2711963  Singapore Centre for Environmental Life Sciences Engineering
# SRX2711964  Singapore Centre for Environmental Life Sciences Engineering
# SRX2711965  Singapore Centre for Environmental Life Sciences Engineering
# SRX2711966  Singapore Centre for Environmental Life Sciences Engineering
# SRX2711967  Singapore Centre for Environmental Life Sciences Engineering
#
#             InsertSize  InsertDev     SRA ID  GEO Series GEO Sample  \
# SRX7442752         0.0  9734641.0  GSE142611  GSM4232895   32071223
# SRX7442753         0.0  9734642.0  GSE142611  GSM4232896   32071223
# SRX7442754         0.0  9734643.0  GSE142611  GSM4232897   32071223
# SRX7442755         0.0  9734644.0  GSE142611  GSM4232898   32071223
# SRX7442756         0.0  9734645.0  GSE142611  GSM4232899   32071223
# ...                ...        ...        ...         ...        ...
# SRX2711963         0.0  3911992.0       None        None   29090193
# SRX2711964         0.0  3911993.0       None        None   29090193
# SRX2711965         0.0  3911994.0       None        None   29090193
# SRX2711966         0.0  3911995.0       None        None   29090193
# SRX2711967         0.0  3911996.0       None        None   29090193
#
#                   PMID            Biosample ID biosample_strain strain_final  \
# SRX7442752  32071223.0                    PA01             PAO1    wild type
# SRX7442753  32071223.0                    PA01             PAO1    wild type
# SRX7442754  32071223.0                    PA01             PAO1    wild type
# SRX7442755  32071223.0                    PA01             PAO1    wild type
# SRX7442756  32071223.0                    PA01             PAO1    wild type
# ...                ...                     ...              ...          ...
# SRX2711963  29090193.0  PA01Pa01_wildtype_rep1             PAO1    wild type
# SRX2711964  29090193.0           PA01yhjH_rep2             PAO1      delyhjH
# SRX2711965  29090193.0           PA01yhjH_rep1             PAO1      delyhjH
# SRX2711966  29090193.0           PA01wspF_rep2             PAO1      delwspF
# SRX2711967  29090193.0           PA01wspF_rep1             PAO1      delwspF
#
#            biosample_genotype           project      condition       refrence  \
# SRX7442752        NC_002516.2  AB569_EDTA_NaNO2  EDTA_NaNo2_wt  EDTA_NaNo2_wt
# SRX7442753        NC_002516.2  AB569_EDTA_NaNO2  EDTA_NaNo2_wt  EDTA_NaNo2_wt
# SRX7442754        NC_002516.2  AB569_EDTA_NaNO2          NaNO2  EDTA_NaNo2_wt
# SRX7442755        NC_002516.2  AB569_EDTA_NaNO2          NaNO2  EDTA_NaNo2_wt
# SRX7442756        NC_002516.2  AB569_EDTA_NaNO2           EDTA  EDTA_NaNo2_wt
# ...                       ...               ...            ...            ...
# SRX2711963        NC_002516.2     yhjH_knockout  PA_delyhjH_wt  PA_delyhjH_wt
# SRX2711964        NC_002516.2     yhjH_knockout     PA_delyhjH  PA_delyhjH_wt
# SRX2711965        NC_002516.2     yhjH_knockout     PA_delyhjH  PA_delyhjH_wt
# SRX2711966        NC_002516.2     yhjH_knockout     PA_delwspF  PA_delyhjH_wt
# SRX2711967        NC_002516.2     yhjH_knockout     PA_delwspF  PA_delyhjH_wt
#
#            condition_name_old   project_name_old  \
# SRX7442752      EDTA_NaNo2_wt         AB569_PAO1
# SRX7442753      EDTA_NaNo2_wt         AB569_PAO1
# SRX7442754            NaNO2_1         AB569_PAO1
# SRX7442755            NaNO2_3         AB569_PAO1
# SRX7442756             EDTA_1         AB569_PAO1
# ...                       ...                ...
# SRX2711963      PA_delyhjH_wt  Knock_out_delyhjH
# SRX2711964         PA_delyhjH  Knock_out_delyhjH
# SRX2711965         PA_delyhjH  Knock_out_delyhjH
# SRX2711966         PA_delwspF  Knock_out_delyhjH
# SRX2711967         PA_delwspF  Knock_out_delyhjH
#
#                                  full_name replicates refrence_condition_old  \
# SRX7442752  AB569_EDTA_NaNO2:EDTA_NaNo2_wt       None          EDTA_NaNo2_wt
# SRX7442753  AB569_EDTA_NaNO2:EDTA_NaNo2_wt       None          EDTA_NaNo2_wt
# SRX7442754          AB569_EDTA_NaNO2:NaNO2       None          EDTA_NaNo2_wt
# SRX7442755          AB569_EDTA_NaNO2:NaNO2       None          EDTA_NaNo2_wt
# SRX7442756           AB569_EDTA_NaNO2:EDTA       None          EDTA_NaNo2_wt
# ...                                    ...        ...                    ...
# SRX2711963     yhjH_knockout:PA_delyhjH_wt       None          PA_delyhjH_wt
# SRX2711964        yhjH_knockout:PA_delyhjH       None          PA_delyhjH_wt
# SRX2711965        yhjH_knockout:PA_delyhjH       None          PA_delyhjH_wt
# SRX2711966        yhjH_knockout:PA_delwspF       None          PA_delyhjH_wt
# SRX2711967        yhjH_knockout:PA_delwspF       None          PA_delyhjH_wt
#
#            strain_description base_media  carbon_source nitrogen_source  \
# SRX7442752                 LB       None            NaN         Aerobic
# SRX7442753                 LB       None            NaN         Aerobic
# SRX7442754                 LB       None            NaN         Aerobic
# SRX7442755                 LB       None            NaN         Aerobic
# SRX7442756                 LB       None            NaN         Aerobic
# ...                       ...        ...            ...             ...
# SRX2711963              ABTGC       None            NaN            None
# SRX2711964              ABTGC       None            NaN            None
# SRX2711965              ABTGC       None            NaN            None
# SRX2711966              ABTGC       None            NaN            None
# SRX2711967              ABTGC       None            NaN            None
#
#            aerobicity  supplement  temperature        pH growth_phase    OD  \
# SRX7442752       None        37.0          NaN      None         None  None
# SRX7442753       None        37.0          NaN      None         None  None
# SRX7442754       None        37.0          NaN      None         None  None
# SRX7442755       None        37.0          NaN      None         None  None
# SRX7442756       None        37.0          NaN      None         None  None
# ...               ...         ...          ...       ...          ...   ...
# SRX2711963       None        37.0          NaN  late log         None  None
# SRX2711964       None        37.0          NaN  late log         None  None
# SRX2711965       None        37.0          NaN  late log         None  None
# SRX2711966       None        37.0          NaN  late log         None  None
# SRX2711967       None        37.0          NaN  late log         None  None
#
#             additional_notes  passed_fastqc  passed_reads_mapped_to_CDS  \
# SRX7442752               NaN           True                        True
# SRX7442753               NaN           True                        True
# SRX7442754               NaN           True                        True
# SRX7442755               NaN           True                        True
# SRX7442756               NaN           True                        True
# ...                      ...            ...                         ...
# SRX2711963               NaN           True                        True
# SRX2711964               NaN           True                        True
# SRX2711965               NaN           True                        True
# SRX2711966               NaN           True                        True
# SRX2711967               NaN           True                        True
#
#             passed_global_correlation  passed_similar_replicates  \
# SRX7442752                        1.0                       True
# SRX7442753                        1.0                       True
# SRX7442754                        1.0                       True
# SRX7442755                        1.0                       True
# SRX7442756                        1.0                       True
# ...                               ...                        ...
# SRX2711963                        1.0                       True
# SRX2711964                        1.0                       True
# SRX2711965                        1.0                       True
# SRX2711966                        1.0                       True
# SRX2711967                        1.0                       True
#
#             passed_number_replicates
# SRX7442752                      True
# SRX7442753                      True
# SRX7442754                      True
# SRX7442755                      True
# SRX7442756                      True
# ...                              ...
# SRX2711963                      True
# SRX2711964                      True
# SRX2711965                      True
# SRX2711966                      True
# SRX2711967                      True
#
# [411 rows x 55 columns]

# %%
#ica_data.sample_table.to_csv('paeru_sample_table.csv')
ica_data.sample_table = pd.read_csv('paeru_sample_table.csv', index_col = 0)

# %%
# add replicate numbers for each sample
ica_data.sample_table = ica_data.sample_table.rename({'replicates':'replicate'}, axis = 1)
for name, group in ica_data.sample_table.groupby(['project', 'condition']):
    ica_data.sample_table.loc[group.index, 'replicate'] = range(1, group.shape[0]+1)

# make sample names that include replicate number
ica_data.sample_table = ica_data.sample_table.rename({'full_name':'full_condition_name'}, axis = 1)
ica_data.sample_table['name'] = \
    ica_data.sample_table.full_condition_name + ':' + \
    ica_data.sample_table.replicate.astype(str)

# important: "Sample" is already a column and we don't want it to be
ica_data.sample_table = ica_data.sample_table.rename({
    'Sample': 'SRS_Sample',
    'name': 'sample'
    }, axis = 1)

# %% [markdown]
# ## iModulon Table

# %%
# deal with the tf_issues.has_gene column
tf_genes = {'PA4021':'eatR',
            'PA0367':'laoR',
            'PA3184':'hexR',
            'PA2511':'antR',
            'PA5499':'zur',
            'PA1663':'sfa2',
            'PA0071':'tagR2',
            'PA4769':'lldR',
            'PA1978':'erbR',
            'PA2020':'mexZ',
            'PA4596':'esrC',
            'PA0716':'xisF4',
            'PA1335':'aauR',
            'PA2523':'czcR',
            'PA0186':'atsR',
            'PA3204':'cpxR',
            'PA0279':'ydfF',
            'PA3381':'phnF',
            'PA5085':'dguR',
            'PA4184':'souR',
            'PA2491':'mexS',
            'PA2449':'gcsR',
            'PA2010':'hmgR',
            'PA0217':'mdcR'
           }

for locus, gene in tf_genes.items():
    if not(locus in ica_data.gene_table.index):
        print(locus)
    ica_data.gene_table.gene_name[locus] = gene
# Out:
# <ipython-input-10-fa90ecd9bd8a>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ica_data.gene_table.gene_name[locus] = gene

# %%
# "Novel iModulon" is not a regulator
ica_data.imodulon_table.loc['RiPP', 'regulator'] = None

# %%
# capitalization error in the TRN
ica_data.trn.regulator = ica_data.trn.regulator.replace('Prrf', 'PrrF')
ica_data.tf_links['PrrF'] = 'https://www.pseudomonas.com/primarySequenceFeature/list?strain_ids=107&term=Pseudomonas+aeruginosa+PAO1+%28Reference%29&c1=name&v1=PrrF&e1=1&assembly=complete'

# %%
# category typo & capitalization
ica_data.imodulon_table.Category = ica_data.imodulon_table.Category.replace({
    'Quorum sening ': 'Quorum Sensing',
    'Quorum sensing': 'Quorum Sensing',
    'Defense mechanisms': 'Defense Mechanisms',
    'Secretion system': 'Secretion System',
    'Biosynthetic gene cluster': 'Biosynthetic Gene Cluster',
    'Stress response':'Stress Response'
    })

# %% [markdown]
# ## Double-check

# %%
table_issues, tf_issues, missing_gene_links, missing_dois = \
    imodulondb_compatibility(ica_data)

print('--Table Issues--')
display(table_issues)
print('--TF Issues--')
display(tf_issues)
print('--Missing Gene Links--')
display(missing_gene_links.values)
print('--Missing DOIs--')
display(missing_dois.values)
# Out:
# --Table Issues--
#         Table    Missing Column                                       Solution
# 0  iModulonDB  publication_link  The publication name will not be a hyperlink.
# 1        Gene            operon                  Operon info will not display.
# 2      Sample      n_replicates         This column will be generated for you.
# 3    iModulon              name             imodulon_table.index will be used.
# 4    iModulon           n_genes          This column will be computed for you.
# --TF Issues--
#                in_trn has_link has_gene
# Sigma factor X   True     True    False
# EutR             True     True    False
# RutR             True     True    False
# AHL              True     True    False
# TagR1            True     True    False
# PrpR             True     True    False
# NagQ             True     True    False
# PrrF             True     True    False
# k-opioid         True     True    False
# Cobalamin        True     True    False
# ParB             True     True    False
# NorR             True     True    False
# HypR             True     True    False
# PhnR             True     True    False
# Sigma-70         True     True    False
# --Missing Gene Links--
# array([], dtype=float64)
# --Missing DOIs--
# array(['Paeru_0017', 'Paeru_0018', 'Paeru_0019', 'Paeru_0020',
#        'Paeru_0033', 'Paeru_0034', 'Paeru_0035', 'Paeru_0036',
#        'Paeru_0037', 'Paeru_0038', 'Paeru_0039', 'Paeru_0040',
#        'Paeru_0041', 'Paeru_0042', 'Paeru_0043', 'Paeru_0044',
#        'Paeru_0045', 'Paeru_0046', 'Paeru_0047', 'Paeru_0048',
#        'Paeru_0049', 'Paeru_0050', 'Paeru_0051', 'Paeru_0052',
#        'Paeru_0053', 'Paeru_0056', 'Paeru_0057', 'Paeru_0058',
#        'Paeru_0059', 'Paeru_0060', 'Paeru_0061', 'Paeru_0062',
#        'Paeru_0063', 'Paeru_0064', 'Paeru_0065', 'Paeru_0066',
#        'Paeru_0068', 'Paeru_0069', 'Paeru_0070', 'Paeru_0071',
#        'Paeru_0072', 'Paeru_0073', 'Paeru_0074', 'Paeru_0075',
#        'Paeru_0077', 'Paeru_0106', 'Paeru_0107', 'Paeru_0111',
#        'Paeru_0112', 'Paeru_0131', 'Paeru_0132', 'Paeru_0133',
#        'Paeru_0134', 'Paeru_0135', 'Paeru_0136', 'Paeru_0137',
#        'Paeru_0138', 'Paeru_0161', 'Paeru_0162', 'Paeru_0166',
#        'Paeru_0167', 'Paeru_0220', 'Paeru_0221', 'Paeru_0258',
#        'Paeru_0259', 'Paeru_0260', 'Paeru_0261', 'Paeru_0262',
#        'Paeru_0263', 'Paeru_0264', 'Paeru_0265', 'Paeru_0266',
#        'Paeru_0267', 'Paeru_0268', 'Paeru_0269', 'Paeru_0270',
#        'Paeru_0271', 'Paeru_0282', 'Paeru_0283', 'Paeru_0284',
#        'Paeru_0285', 'Paeru_0286', 'Paeru_0287'], dtype=object)

# %% [markdown]
# ## Save

# %%
save_to_json(ica_data, 'final_im_objects/p_aeruginosa_modulome_imdb.json')

# %% [markdown]
# ## Export

# %%
categories = ['Carbon Source Utilization',
              'Amino Acid and Nucleotide Biosynthesis',
              'Energy Metabolism',
              'Metal Homeostasis',
              'Miscellaneous Metabolism',
              'Translational', 
              'Biosynthetic Gene Cluster',
              'Secretion System',
              'Structural Components',
              'Quorum Sensing',
              'Stress Response',
              'Defense Mechanisms',
              'Prophages',
              'Singlet', 
              'Uncharacterized'
             ]

# %%
imodulondb_export(ica_data, '../iModulonDB', cat_order = categories)
